# %%
# pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in d:\infosys sb\bankbot_ai\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in d:\infosys sb\bankbot_ai\lib\site-packages (from ipywidgets) (9.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\infosys sb\bankbot_ai\lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: colorama>=0.4.4 in d:\infosys sb\bankbot_ai\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in d:\infosys sb\bankbot_ai\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in d:\infosys sb\bankbot_ai\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in d:\infosys sb\bankbot_ai\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in d:\infosys sb\bankbot_ai\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\infosys sb\bankbot_ai\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in d:\infosys sb\bankbot_ai\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in d:\infosys sb\bankbot_ai\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in d:\infosys sb\bankbot_ai\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\infosys sb\bankbot_ai\lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in d:\infosys sb\bankbot_ai\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\infosys sb\bankbot_ai\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in d:\infosys sb\bankbot_ai\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/914.9 kB ? eta -:--:--
#    ---------------------- ----------------- 524.3/914.9 kB 2.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 524.3/914.9 kB 2.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 524.3/914.9 kB 2.0 MB/s eta 0:00:01
#    -------------------------------- ----- 786.4/914.9 kB 617.2 kB/s eta 0:00:01
#    ---------------------------------------- 914.9/914.9 kB 697.7 kB/s  0:00:01
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 1.8 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.2 MB 1.9 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.2 MB 1.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.2 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 1.2 MB/s  0:00:01
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
#
#    ------------- -------------------------- 1/3 [jupyterlab_widgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    ---------------------------------------- 3/3 [ipywidgets]
#
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import torch
import numpy as np
import json

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    Trainer,
    TrainingArguments
)

# %%
with open("../nlu_engine/intents.json", "r", encoding="utf-8") as f:
    data = json.load(f)

texts = []
labels = []

label2id = {intent["name"]: i for i, intent in enumerate(data["intents"])}
id2label = {i: name for name, i in label2id.items()}

for intent in data["intents"]:
    for example in intent["examples"]:
        texts.append(example)
        labels.append(label2id[intent["name"]])

# %%
print(f"Total examples: {len(texts)}")
display(texts[:5])
# Out:
# Total examples: 83
# ['Show balance for my savings account',
#  'How much money do I have in my current account?',
#  'Check balance of my savings',
#  'Can you tell me my account balance?',
#  "What's the balance in my checking account?"]

# %%
print(f"Total labels: {len(set(labels))}")
# Out:
# Total labels: 6

# %%
shown_labels = len(label2id)
print(f"Shown labels: {shown_labels}")
print(f"Label to ID mapping: {label2id}")
print(f"ID to Label mapping: {id2label}")
# Out:
# Shown labels: 6
# Label to ID mapping: {'check_balance': 0, 'transfer_money': 1, 'card_block': 2, 'find_atm': 3, 'interest': 4, 'loan': 5}
# ID to Label mapping: {0: 'check_balance', 1: 'transfer_money', 2: 'card_block', 3: 'find_atm', 4: 'interest', 5: 'loan'}

# %%
train_texts, val_texts, train_labels, val_labels = train_test_split(texts,labels,test_size=0.2,random_state=42)

# %%
MODEL_NAME = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
def tokenize(texts, labels):
    encodings = tokenizer(
        texts,
        truncation=True,
        padding=True,
        max_length=128,
        return_tensors="pt"
    )
    encodings["labels"] = torch.tensor(labels)
    return encodings

# %%
class IntentDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __len__(self):
        return len(self.encodings["labels"])

    def __getitem__(self, idx):
        return {k: v[idx] for k, v in self.encodings.items()}

# %%
train_encodings = tokenize(train_texts, train_labels)
val_encodings = tokenize(val_texts, val_labels)

train_dataset = IntentDataset(train_encodings)
val_dataset = IntentDataset(val_encodings)

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=len(label2id)
)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="../models/intent_model_2",
    num_train_epochs=100,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    learning_rate=2e-5,  # 0.00002
    logging_dir="../models/intent_model_2/logs",
    do_eval=True,
    save_steps=500
)

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=1)

    return {
        "accuracy": accuracy_score(labels, predictions),
        "f1": f1_score(labels, predictions, average="weighted")
    }

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# C:\Users\aitha\AppData\Local\Temp\ipykernel_23916\2721217396.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
# d:\Infosys SB\bankbot_ai\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='900' max='900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [900/900 08:31, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.167700</td>
#     </tr>
#   </tbody>
# </table><p>
# d:\Infosys SB\bankbot_ai\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# TrainOutput(global_step=900, training_loss=0.09517466584841411, metrics={'train_runtime': 516.6176, 'train_samples_per_second': 12.775, 'train_steps_per_second': 1.742, 'total_flos': 30738768667200.0, 'train_loss': 0.09517466584841411, 'epoch': 100.0})

# %%
def predict_intent(text):
    inputs = tokenizer(text, return_tensors="pt")

    with torch.no_grad():
        outputs = model(**inputs)

    probs = torch.softmax(outputs.logits, dim=1)
    pred_id = torch.argmax(probs).item()

    return {
        "intent": id2label[pred_id],
        "confidence": probs[0][pred_id].item()
    }

# %%
predict_intent("I want to block my debit card")
# Out:
# {'intent': 'card_block', 'confidence': 0.9967018961906433}

# %%
predict_intent("Please transfer $250 to my friend")
# Out:
# {'intent': 'transfer_money', 'confidence': 0.9982580542564392}

# %%
predict_intent("How can I open a new savings account?")
# Out:
# {'intent': 'check_balance', 'confidence': 0.9651415348052979}

# %%
predict_intent("transfer 500 dollars to john")
# Out:
# {'intent': 'transfer_money', 'confidence': 0.9980048537254333}
